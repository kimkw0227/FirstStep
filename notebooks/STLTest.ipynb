# %%
from keras.layers import Input, Dense
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
encoding_dim = 32

# %%
input_img = Input(shape=(784,))

# %%
encoded = Dense(encoding_dim, activation='relu')(input_img)
# Out:
# WARNING:tensorflow:From C:\Users\KingKwan\Anaconda2\envs\FirstStep\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
decoded = Dense(784,activation='sigmoid')(encoded)

# %%
autoencoder = Model(input_img,decoded)

# %%
from keras.datasets import mnist
import numpy as np

# %%
encoder = Model(input_img,encoded)
encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input,decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adadelta',loss='binary_crossentropy')

# %%
(x_train,_),(x_test,_) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train),np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test),np.prod(x_test.shape[1:])))

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
x_test.shape
# Out:
# (10000, 784)

# %%
autoencoder.fit(x_train,x_train,epochs=50,batch_size=256,shuffle=True
                ,validation_data=(x_test,x_test))
# Out:
# WARNING:tensorflow:From C:\Users\KingKwan\Anaconda2\envs\FirstStep\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.3574 - val_loss: 0.2712
# Epoch 2/50
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.2646 - val_loss: 0.2542
# Epoch 3/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.2432 - val_loss: 0.2292
# Epoch 4/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2202 - val_loss: 0.2092
# Epoch 5/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.2039 - val_loss: 0.1960
# Epoch 6/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1927 - val_loss: 0.1866
# Epoch 7/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1844 - val_loss: 0.1794
# Epoch 8/50
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1777 - val_loss: 0.1733
# Epoch 9/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.1720 - val_loss: 0.1680
# Epoch 10/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1670 - val_loss: 0.1634
# Epoch 11/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1625 - val_loss: 0.1592
# Epoch 12/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1585 - val_loss: 0.1552
# Epoch 13/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1548 - val_loss: 0.1517
# Epoch 14/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1515 - val_loss: 0.1486
# Epoch 15/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1485 - val_loss: 0.1457
# Epoch 16/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1457 - val_loss: 0.1430
# Epoch 17/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1431 - val_loss: 0.1406
# Epoch 18/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1406 - val_loss: 0.1380
# Epoch 19/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1383 - val_loss: 0.1358
# Epoch 20/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1361 - val_loss: 0.1336
# Epoch 21/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1340 - val_loss: 0.1316
# Epoch 22/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1320 - val_loss: 0.1295
# Epoch 23/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1300 - val_loss: 0.1276
# Epoch 24/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1281 - val_loss: 0.1258
# Epoch 25/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1263 - val_loss: 0.1240
# Epoch 26/50
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.1245 - val_loss: 0.1222
# Epoch 27/50
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1228 - val_loss: 0.1205
# Epoch 28/50
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1212 - val_loss: 0.1189
# Epoch 29/50
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.1197 - val_loss: 0.1175
# Epoch 30/50
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1183 - val_loss: 0.1161
# Epoch 31/50
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1169 - val_loss: 0.1148
# Epoch 32/50
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.1157 - val_loss: 0.1135
# Epoch 33/50
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.1145 - val_loss: 0.1124
# Epoch 34/50
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.1134 - val_loss: 0.1113
# Epoch 35/50
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1124 - val_loss: 0.1103
# Epoch 36/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1115 - val_loss: 0.1094
# Epoch 37/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1106 - val_loss: 0.1086
# Epoch 38/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1098 - val_loss: 0.1078
# Epoch 39/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1090 - val_loss: 0.1070
# Epoch 40/50
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1083 - val_loss: 0.1063
# Epoch 41/50
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.1076 - val_loss: 0.1057
# Epoch 42/50
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1070 - val_loss: 0.1051
# Epoch 43/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1064 - val_loss: 0.1045
# Epoch 44/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1059 - val_loss: 0.1040
# Epoch 45/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1054 - val_loss: 0.1035
# Epoch 46/50
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1049 - val_loss: 0.1030
# Epoch 47/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1044 - val_loss: 0.1026
# Epoch 48/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1040 - val_loss: 0.1021
# Epoch 49/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1036 - val_loss: 0.1018
# Epoch 50/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1032 - val_loss: 0.1014

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
import matplotlib.pyplot as plt

# %%
n = 15
plt.figure(figsize=(20,4))
for i in range(n):
    ax = plt.subplot(2,n,i+1)
    plt.imshow(x_test[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    ax = plt.subplot(2,n,i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
